# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cces = pd.read_csv("cces_example_data.csv")

# %%
cces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %% [markdown]
# Scroll through the matplotlib figure examples Links to an external site. and pick one style of figure you would like to learn how to create, then in a Markdown cell, explain what kind of data you would like to represent using that figure.

# %% [markdown]
# I would go with [Time Series Histogram](https://matplotlib.org/stable/gallery/statistics/time_series_histogram.html#sphx-glr-gallery-statistics-time-series-histogram-py). Largely in part because it's rather nice to look at. I feel like it would be good for judging a dataset of user engagement; session durations, clicks and similar.

# %%
fig1, ax1 = plt.subplots(1,2)
plt.show()

# %%
fig, ax = plt.subplots(1,2, layout = "constrained")
ax[0].set_xlabel("Age Histogram")
ax[1].set_xlabel("Age Histogram")

ax[0].set_ylabel("Political Identity")
ax[1].set_ylabel("Political Identity")
plt.show()

# %% [markdown]
# In a new code cell, create and show a figure that includes one axis with a bar plot of the `Evaluation` variable

# %%
eval_freq = cces.groupby("Evaluation").size()
eval_freq
# Out:
# Evaluation
# 0    365
# 1     48
# 2    202
# 3     44
# dtype: int64

# %%
fig1, ax1 = plt.subplots()
x = eval_freq.index
y = eval_freq.values
ax1.bar(x, y)
ax1.set_xlabel("Evaluation")
ax1.set_ylabel("Frequency")
plt.show()

# %% [markdown]
# In a new code cell, create and show a figure that includes one axis with a scatter plot of the `ConMediaUse` and `ImmiPhobia` variable

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(cces["ImmiPhobia"], cces["age"], color = "yellow", label ="ImmiPhobia")
ax2.scatter(cces["ConMediaUse"],cces["age"], color = "blue", label ="ConMediaUse")
ax2.set_xlabel("ConMediaUse and ImmiPhobia")
ax2.set_ylabel("Age")
plt.show()

# %%
cces["ConMediaUse"].describe()
# Out:
# count    659.000000
# mean       2.361659
# std        1.279250
# min        1.000000
# 25%        1.333333
# 50%        2.000000
# 75%        3.000000
# max        6.000000
# Name: ConMediaUse, dtype: float64

# %%
cces["ImmiPhobia"].describe()
# Out:
# count    659.000000
# mean       2.327011
# std        1.040428
# min        1.000000
# 25%        1.500000
# 50%        2.500000
# 75%        3.000000
# max        5.000000
# Name: ImmiPhobia, dtype: float64
